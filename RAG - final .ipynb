# %%
import os
import pandas as pd
import shutil
from dataclasses import dataclass

from langchain.llms import OpenAI
from langchain.embeddings import OpenAIEmbeddings
from langchain.evaluation import load_evaluator
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain.vectorstores.chroma import Chroma
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

from typing import List
from langchain.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field, NonNegativeInt
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA

from langchain.document_loaders.csv_loader import CSVLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma

# %%
import os
import openai

os.environ["OPENAI_API_KEY"] = "YOUR API KEY"
os.environ["OPENAI_BASE_URL"] = "https://openai.vocareum.com/v1"

openai.api_key = "YOUR API KEY"
openai.api_base = "https://openai.vocareum.com/v1"


prompt = """
Generate 10 synthetic real estate listings.
Return ONLY valid CSV format (no backticks, no commentary).
Columns:
Neighborhood,Price,Bedrooms,Bathrooms,House Size,Description

Rules:
- Bedrooms must be an integer between 1 and 5.
- Bathrooms must be an integer between 1 and 4.
- Price must be a realistic positive number.
- House Size must be a positive number in square feet.
- Add a proper in detail description for each estate.
- There should not be any None/Null/Void Cell in the CSV
"""

response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[{"role": "user", "content": prompt}],
    temperature=0.5
)

csv_text = response.choices[0].message.content.strip()

# Save directly as CSV file
with open("listings.csv", "w", encoding="utf-8") as f:
    f.write(csv_text)

print("CSV generated successfully: listings.csv")

# %%
import openai

# %%
from langchain import LLMChain
from langchain.chains.question_answering import load_qa_chain

# %%
import os

OPENAI_API_KEY = "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"
OPENAI_BASE = "https://openrouter.ai/api/v1"

os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
os.environ["OPENAI_API_BASE"] = OPENAI_BASE

# %%
MODEL_NAME = 'openai/gpt-3.5-turbo'

# %%
llm = OpenAI(model_name=MODEL_NAME, 
             temperature=0, 
             api_key=OPENAI_API_KEY , 
             openai_api_base="https://openrouter.ai/api/v1")

# %%
INSTRUCTION = "Generate a CSV file with at least 20 real estate listings."
SAMPLE_LISTING = \
"""
Neighborhood: Green Oaks
Price: $800,000
Bedrooms: 3
Bathrooms: 2
House Size: 2,000 sqft

Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.

Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
"""

# %%
class RealEstateListing(BaseModel):
    """
    A real estate listing.
    
    Attributes:
    - neighborhood: str
    - price: NonNegativeInt
    - bedrooms: NonNegativeInt
    - bathrooms: NonNegativeInt
    - house_size: NonNegativeInt
    - description: str
    - neighborhood_description: str
    """
    neighborhood: str = Field(description="The neighborhood where the property is located")
    price: NonNegativeInt = Field(description="The price of the property in USD")
    bedrooms: NonNegativeInt = Field(description="The number of bedrooms in the property")
    bathrooms: NonNegativeInt = Field(description="The number of bathrooms in the property")
    house_size: NonNegativeInt = Field(description="The size of the house in square feet")
    description: str = Field(description="A description of the property")
    neighborhood_description: str = Field(description="A description of the neighborhood.")  

class ListingCollection(BaseModel):
    """
    A collection of real estate listings.
    
    Attributes:
    - listings: List[RealEstateListing]
    """
    listings: List[RealEstateListing] = Field(description="A list of real estate listings")

# %%
parser = PydanticOutputParser(pydantic_object=ListingCollection)

# %%
# printing the prompt
prompt = PromptTemplate(
    template="{instruction}\n{sample}\n{format_instructions}\n",
    input_variables=["instruction", "sample"],
    partial_variables={"format_instructions": parser.get_format_instructions},
)

query = prompt.format(
    instruction=INSTRUCTION,
    sample=SAMPLE_LISTING,
)
print(query)
# Out:
# Generate a CSV file with at least 20 real estate listings.
#
# Neighborhood: Green Oaks
# Price: $800,000
# Bedrooms: 3
# Bathrooms: 2
# House Size: 2,000 sqft
#
# Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.
#
# Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"description": "A collection of real estate listings.\n\nAttributes:\n- listings: List[RealEstateListing]", "properties": {"listings": {"title": "Listings", "description": "A list of real estate listings", "type": "array", "items": {"$ref": "#/definitions/RealEstateListing"}}}, "required": ["listings"], "definitions": {"RealEstateListing": {"title": "RealEstateListing", "description": "A real estate listing.\n\nAttributes:\n- neighborhood: str\n- price: NonNegativeInt\n- bedrooms: NonNegativeInt\n- bathrooms: NonNegativeInt\n- house_size: NonNegativeInt\n- description: str\n- neighborhood_description: str", "type": "object", "properties": {"neighborhood": {"title": "Neighborhood", "description": "The neighborhood where the property is located", "type": "string"}, "price": {"title": "Price", "description": "The price of the property in USD", "minimum": 0, "type": "integer"}, "bedrooms": {"title": "Bedrooms", "description": "The number of bedrooms in the property", "minimum": 0, "type": "integer"}, "bathrooms": {"title": "Bathrooms", "description": "The number of bathrooms in the property", "minimum": 0, "type": "integer"}, "house_size": {"title": "House Size", "description": "The size of the house in square feet", "minimum": 0, "type": "integer"}, "description": {"title": "Description", "description": "A description of the property", "type": "string"}, "neighborhood_description": {"title": "Neighborhood Description", "description": "A description of the neighborhood.", "type": "string"}}, "required": ["neighborhood", "price", "bedrooms", "bathrooms", "house_size", "description", "neighborhood_description"]}}}
# ```

# %%
llm = ChatOpenAI(
    model_name=MODEL_NAME,
    temperature=0,
    api_key=OPENAI_API_KEY, # Use the API key
    openai_api_base="https://openrouter.ai/api/v1" # Specify the custom base URL
)

# %%
response_msg = llm.invoke(query)
response_content = response_msg.content

# %%
# create a dataframe from the response
result = parser.parse(response_content)
data_list = [item.dict() for item in result.listings]
df = pd.DataFrame(data_list)
df.head()
# Out:
#            neighborhood    price  bedrooms  bathrooms  house_size  \
# 0            Green Oaks   800000         3          2        2000
# 1             Sunnyvale   950000         4          3        2500
# 2  Downtown Los Angeles  1200000         2          2        1800
# 3      Brooklyn Heights  1500000         5          4        3000
# 4     Pacific Palisades  2500000         6          5        4000
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Located in the desirable neighborhood of Sunny...
# 2  Experience luxury living in the heart of Downt...
# 3  Live in luxury in this spacious 5-bedroom, 4-b...
# 4  Escape to paradise in this luxurious 6-bedroom...
#
#                             neighborhood_description
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Sunnyvale is known for its top-rated schools, ...
# 2  Downtown Los Angeles is a vibrant neighborhood...
# 3  Brooklyn Heights is a historic neighborhood kn...
# 4  Pacific Palisades is a prestigious neighborhoo...

# %%
df.to_csv('real_estate_listings.csv', index_label = 'id')

# %%
df
# Out:
#             neighborhood    price  bedrooms  bathrooms  house_size  \
# 0             Green Oaks   800000         3          2        2000
# 1              Sunnyvale   950000         4          3        2500
# 2   Downtown Los Angeles  1200000         2          2        1800
# 3       Brooklyn Heights  1500000         5          4        3000
# 4      Pacific Palisades  2500000         6          5        4000
# 5            South Beach  1800000         3          3        2200
# 6               Nob Hill  3500000         4          4        2800
# 7             Georgetown  2800000         5          4        3200
# 8          Beverly Hills  5000000         6          6        5000
# 9        Upper East Side  4500000         5          5        4500
# 10          Palm Springs  1200000         4          3        2800
# 11               Tribeca  3000000         3          3        2400
# 12          Venice Beach  1600000         4          3        2600
# 13                  Soho  2800000         3          2        2000
# 14                Malibu  3500000         5          4        3500
# 15          West Village  3200000         4          3        2600
# 16          Santa Monica  2000000         4          3        2800
# 17          Williamsburg  1800000         3          2        2200
# 18        Marina del Rey  2200000         4          3        2600
#
#                                           description  \
# 0   Welcome to this eco-friendly oasis nestled in ...
# 1   Located in the desirable neighborhood of Sunny...
# 2   Experience luxury living in the heart of Downt...
# 3   Live in luxury in this spacious 5-bedroom, 4-b...
# 4   Escape to paradise in this luxurious 6-bedroom...
# 5   Live the Miami lifestyle in this modern 3-bedr...
# 6   Experience luxury living in this elegant 4-bed...
# 7   Live in luxury in this spacious 5-bedroom, 4-b...
# 8   Live like a celebrity in this luxurious 6-bedr...
# 9   Live in luxury in this elegant 5-bedroom, 5-ba...
# 10  Escape to paradise in this modern 4-bedroom, 3...
# 11  Live in luxury in this modern 3-bedroom, 3-bat...
# 12  Live the beach lifestyle in this modern 4-bedr...
# 13  Live in luxury in this stylish 3-bedroom, 2-ba...
# 14  Escape to paradise in this luxurious 5-bedroom...
# 15  Live in luxury in this elegant 4-bedroom, 3-ba...
# 16  Live the California dream in this modern 4-bed...
# 17  Live in luxury in this stylish 3-bedroom, 2-ba...
# 18  Live the coastal lifestyle in this modern 4-be...
#
#                              neighborhood_description
# 0   Green Oaks is a close-knit, environmentally-co...
# 1   Sunnyvale is known for its top-rated schools, ...
# 2   Downtown Los Angeles is a vibrant neighborhood...
# 3   Brooklyn Heights is a historic neighborhood kn...
# 4   Pacific Palisades is a prestigious neighborhoo...
# 5   South Beach is a vibrant neighborhood known fo...
# 6   Nob Hill is a historic neighborhood known for ...
# 7   Georgetown is a historic neighborhood known fo...
# 8   Beverly Hills is a world-renowned neighborhood...
# 9   The Upper East Side is a historic neighborhood...
# 10  Palm Springs is a popular vacation destination...
# 11  Tribeca is a hip neighborhood known for its co...
# 12  Venice Beach is a bohemian neighborhood known ...
# 13  Soho is a fashionable neighborhood known for i...
# 14  Malibu is a prestigious neighborhood known for...
# 15  The West Village is a charming neighborhood kn...
# 16  Santa Monica is a vibrant beach town known for...
# 17  Williamsburg is a hip neighborhood known for i...
# 18  Marina del Rey is a picturesque waterfront nei...

# %% [markdown]
# ## Vector Database .

# %%
# --- THE FIX: Change CHROMA_PATH to use /tmp ---
CHROMA_PATH = "chroma2" # We are now saving in the system's temp folder
CSV_PATH = "real_estate_listings.csv"


# --- 2. CREATE THE CONFIGURED EMBEDDING FUNCTION ---
embedding_function = OpenAIEmbeddings(
    openai_api_key=OPENAI_API_KEY,
    openai_api_base=OPENAI_BASE,
)


# --- 3. LOAD, SPLIT, AND SAVE (No changes here) ---
loader = CSVLoader(file_path="real_estate_listings.csv")
docs = loader.load()


text_splitter = CharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=0,
)

chunks = text_splitter.split_documents(docs)
print(f"Split {len(docs)} documents into {len(chunks)} chunks.")


os.makedirs(CHROMA_PATH, exist_ok=True)
print(f"Created new directory at {CHROMA_PATH}.")

print("Attempting to save to Chroma...")
db = Chroma.from_documents(
    chunks,
    embedding_function, # <-- Use the pre-configured instance
    persist_directory=CHROMA_PATH
)
db.persist()
print(f"Successfully saved {len(chunks)} chunks to {CHROMA_PATH}.")
# Out:
# Split 19 documents into 19 chunks.
# Created new directory at chroma2.
# Attempting to save to Chroma...
# Successfully saved 19 chunks to chroma2.

# %%
# # SEMANTIC SEARCH QUERY
# user_query = "Recommend the house with the beach "

# results = db.similarity_search(user_query, k=5)

# for i, r in enumerate(results, 1):
#     print(f"\n--- Result {i} ---")

#     # Print metadata (raw title-level info)
#     for key, value in r.metadata.items():
#         print(f"{key}: {value}")

# %% [markdown]
# ## Step 2

# %%
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma

# Load CSV
loader = CSVLoader(file_path="real_estate_listings.csv")
docs = loader.load()

# Split long descriptions if needed
splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
split_docs = splitter.split_documents(docs)

# Embeddings + ChromaDB
embeddings = OpenAIEmbeddings()
db = Chroma.from_documents(split_docs, embeddings)

# %%
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma

# SEMANTIC SEARCH QUERY
user_query = "Recommend the house with ocean with coastal  "

# Retrieve top 5 similar documents
results = db.similarity_search(user_query, k=5)

for i, r in enumerate(results, 1):
    print(f"\n--- Result {i} ---")
    print(r.page_content)
# Out:
# --- Result 1 ---
# id: 4
# neighborhood: Pacific Palisades
# price: 2500000
# bedrooms: 6
# bathrooms: 5
# house_size: 4000
# description: Escape to paradise in this luxurious 6-bedroom, 5-bathroom estate in Pacific Palisades. The home features a grand foyer, formal living and dining rooms, and a gourmet kitchen with custom cabinetry and high-end appliances. The master suite offers a private balcony with ocean views, a fireplace, and a spa-like bathroom. Entertain guests in the backyard oasis with a pool, spa, and outdoor kitchen. Enjoy the coastal lifestyle in this exclusive enclave.
# neighborhood_description: Pacific Palisades is a prestigious neighborhood nestled between the Santa Monica Mountains and the Pacific Ocean. Explore the nearby hiking trails, beaches, and upscale shops and restaurants in this upscale coastal community.
#
# --- Result 2 ---
# id: 5
# neighborhood: South Beach
# price: 1800000
# bedrooms: 3
# bathrooms: 3
# house_size: 2200
# description: Live the Miami lifestyle in this modern 3-bedroom, 3-bathroom condo in South Beach. The open floor plan features floor-to-ceiling windows with breathtaking ocean views, a gourmet kitchen with sleek appliances, and a spacious living room with a balcony. The master suite offers a walk-in closet and a luxurious en-suite bathroom. Enjoy the building's amenities, including a pool, fitness center, and 24-hour concierge.
# neighborhood_description: South Beach is a vibrant neighborhood known for its white sand beaches, trendy nightlife, and Art Deco architecture. Walk to the nearby restaurants, bars, and boutiques, or relax on the beach and soak up the sun in this iconic Miami neighborhood.
#
# --- Result 3 ---
# id: 18
# neighborhood: Marina del Rey
# price: 2200000
# bedrooms: 4
# bathrooms: 3
# house_size: 2600
# description: Live the coastal lifestyle in this modern 4-bedroom, 3-bathroom home in the waterfront community of Marina del Rey. The open floor plan features vaulted ceilings, skylights, and a gourmet kitchen with stainless steel appliances. Relax in the private backyard with a hot tub and outdoor dining area. Enjoy the indoor-outdoor living in this stylish Marina del Rey retreat.
# neighborhood_description: Marina del Rey is a picturesque waterfront neighborhood known for its marinas, yacht clubs, and waterfront dining. Walk to the nearby beaches, bike paths, and boat rentals, or explore the local shops and restaurants in this laid-back Los Angeles enclave.
#
# --- Result 4 ---
# id: 16
# neighborhood: Santa Monica
# price: 2000000
# bedrooms: 4
# bathrooms: 3
# house_size: 2800
# description: Live the California dream in this modern 4-bedroom, 3-bathroom home in the beachside community of Santa Monica. The open floor plan features vaulted ceilings, skylights, and a gourmet kitchen with stainless steel appliances. Relax in the private backyard with a pool, spa, and outdoor dining area. Enjoy the indoor-outdoor living in this stylish Santa Monica retreat.
# neighborhood_description: Santa Monica is a vibrant beach town known for its sandy beaches, trendy shops, and outdoor activities. Walk to the nearby pier, boardwalk, and beach, or explore the local farmers' markets and cafes in this laid-back Los Angeles enclave.
#
# --- Result 5 ---
# id: 12
# neighborhood: Venice Beach
# price: 1600000
# bedrooms: 4
# bathrooms: 3
# house_size: 2600
# description: Live the beach lifestyle in this modern 4-bedroom, 3-bathroom home in the eclectic neighborhood of Venice Beach. The open floor plan features vaulted ceilings, skylights, and a gourmet kitchen with stainless steel appliances. Relax in the private backyard with a hot tub and outdoor dining area. Enjoy the indoor-outdoor living in this stylish Venice Beach retreat.
# neighborhood_description: Venice Beach is a bohemian neighborhood known for its colorful murals, street performers, and trendy shops. Walk to the nearby boardwalk, canals, and beach, or explore the local art galleries and cafes in this laid-back Los Angeles enclave.

# %% [markdown]
# ##  Semantic Search Using RAG

# %%
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI

# LLM
llm = OpenAI(
    model_name="gpt-3.5-turbo",
    temperature=0,
    max_tokens=500
)

# Build Retriever
retriever = db.as_retriever(search_kwargs={"k": 5})

# RAG Chain
rag = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever
)

query = "Recommend the house with ocean view  "

use_chain_helper = False
if use_chain_helper:
    rag = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=db.as_retriever())
    print(rag.run(query))
else:
    similar_docs = db.similarity_search(query, k=5)
    prompt = PromptTemplate(
        template="{query}\nContext: {context}",
        input_variables=["query", "context"],
    )
    chain = load_qa_chain(llm, prompt = prompt, chain_type="stuff")
    print(chain.run(input_documents=similar_docs, query = query))
# Out:
# /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages/langchain_community/llms/openai.py:249: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain_community.chat_models import ChatOpenAI`
#   warnings.warn(
# /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages/langchain_community/llms/openai.py:1070: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain_community.chat_models import ChatOpenAI`
#   warnings.warn(
# I recommend the house in Malibu (id: 14) as it offers a luxurious 5-bedroom, 4-bathroom estate with ocean views. The master suite features a private balcony with ocean views, a fireplace, and a spa-like bathroom. The backyard oasis includes a pool, spa, and outdoor kitchen, perfect for entertaining guests. Malibu is a prestigious neighborhood known for its celebrity homes, pristine beaches, and upscale restaurants, providing the ultimate coastal lifestyle experience.

# %% [markdown]
# ## Personalized Recommendation

# %%
from langchain.memory import ConversationSummaryMemory, ChatMessageHistory
from langchain.prompts import PromptTemplate
from langchain.chains import ConversationalRetrievalChain
from langchain.llms import OpenAI
from langchain_community.chat_models import ChatOpenAI

# %%
# ----------------------------------------------------
# 1. PERSONAL QUESTIONS
# ----------------------------------------------------
personal_questions = [
    "What is your ideal number of bedrooms?",
    "What kind of neighborhood do you prefer?",
    "What is your maximum budget?",
    "Which amenities matter most to you?",
    "Do you prefer urban, suburban, or semi-urban areas?"
]

# ----------------------------------------------------
# 2. HARD-CODED USER ANSWERS (YOU CAN CHANGE THESE)
# ----------------------------------------------------
answers = [
    "I’m looking for a spacious 3-bedroom home.",
    "I prefer like a art based and with island with city view",
    "My budget is around 2800000 ",
    " nearby parks, boutique shops",
    "urban "
]


# ----------------------------------------------------
# 3. BUILD CHAT HISTORY (SIMULATE A FULL CONVERSATION)
# ----------------------------------------------------
history = ChatMessageHistory()

history.add_user_message(
    f"You are a real estate AI assistant. Ask the user {len(personal_questions)} personalization questions."
)

for q, a in zip(personal_questions, answers):
    history.add_ai_message(q)       # AI question
    history.add_user_message(a)     # User answer


# ----------------------------------------------------
# 4. CREATE A WORKING SUMMARIZATION MEMORY (THE FIX)
# ----------------------------------------------------
llm_summary = ChatOpenAI(
    model_name="gpt-3.5-turbo",
    temperature=0,
    max_tokens=200
)

memory = ConversationSummaryMemory(
    llm=llm_summary,
    chat_memory=history,
    memory_key="summary",
    input_key="question",
    return_messages=True
)

# IMPORTANT: Trigger memory to summarize your Q/A
memory.save_context(
    {"question": "Summarize the user's home preferences."},
    {"answer": "Sure, here is the summary."}
)

# Load final summary
summary = memory.load_memory_variables({"question": "Summarize preferences"})

summary_text = memory.predict_new_summary(
    existing_summary="", 
    messages=history.messages
)


# summary_text = summary["summary"]

print("\n\n=== USER PREFERENCE SUMMARY ===")
print(summary_text)


# ----------------------------------------------------
# 5. PERSONALIZED RAG PROMPT
# ----------------------------------------------------
prompt = PromptTemplate(
    template="""
You are a smart real estate advisor.

USER PREFERENCES SUMMARY:
{summary}

RETRIEVED PROPERTY INFORMATION:
{context}

USER QUESTION:
{question}

Answer in a friendly, helpful tone (max 5 sentences).
""",
    input_variables=["summary", "context", "question"]
)

chain_type_kwargs = {"prompt": prompt}


# ----------------------------------------------------
# 6. BUILD FINAL PERSONLIZED RAG SYSTEM
# ----------------------------------------------------
personalized_chain = ConversationalRetrievalChain.from_llm(
    llm=ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0, max_tokens=400),
    chain_type="stuff",
    retriever=db.as_retriever(search_kwargs={"k": 5}),
    combine_docs_chain_kwargs=chain_type_kwargs,
    memory=memory
)


# ----------------------------------------------------
# 7. FINAL QUERY (THIS IS WHERE RETRIEVAL HAPPENS)
# ----------------------------------------------------
final_query =  f"Recommend the best property that matches these preferences: {summary_text}"


# ----------------------------------------------------
# 8. RUN AND PRINT FINAL RECOMMENDATION
# ----------------------------------------------------
response = personalized_chain({
    "question": final_query,
    "chat_history": []
})

print("\n\n=== FINAL PERSONALIZED RECOMMENDATION ===")
print(response["answer"])
# Out:
# === USER PREFERENCE SUMMARY ===
# The real estate AI assistant asks the user 5 personalization questions to determine their ideal home. The user prefers a spacious 3-bedroom home in an art-based neighborhood with a city view, with a budget of around 2800000. They prioritize nearby parks and boutique shops, and prefer an urban area.
#
#
# === FINAL PERSONALIZED RECOMMENDATION ===
# Based on your preferences for a spacious 3-bedroom home in an art-based neighborhood with a city view, I recommend the stylish loft in Soho. This property offers exposed brick walls, high ceilings, and oversized windows with city views, creating a perfect blend of luxury and artistic charm. With a price of 2800000, this home fits within your budget and is located in a trendy neighborhood known for its art galleries and designer boutiques. You'll also enjoy the nearby parks, boutique shops, and upscale cafes in this vibrant downtown Manhattan enclave. Don't miss out on the opportunity to live in luxury in the heart of Soho!
