# %%
# !pip install pandas
# !pip install chromadb
# !pip install langchain
# !pip install numpy
# !pip install -U langchain-openai
# !pip install pydantic
# !pip install shutil
# !pip install openai==0.28
# Out:
# Requirement already satisfied: pandas in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.20.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: chromadb in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: build>=1.0.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (2.12.4)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.23.5)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (6.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.8.2)
# Requirement already satisfied: backoff>=1.10.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2024.2.2)
# Requirement already satisfied: packaging>=19.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (6.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: anyio in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: httpcore==1.* in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: zipp>=0.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.11.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.19.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests-oauthlib in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: durationpy>=0.7 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: coloredlogs in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.1)
# Requirement already satisfied: sympy in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb) (0.34.4)
# Requirement already satisfied: filelock in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.3.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.9)
# Requirement already satisfied: click>=8.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: langchain in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain) (0.4.37)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.12.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain) (1.4.39)
# Requirement already satisfied: requests<3,>=2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (23.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith>=0.1.17->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (3.5.0)
# Requirement already satisfied: certifi in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (3.4)
# Requirement already satisfied: h11>=0.16 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.15)
# Requirement already satisfied: sniffio>=1.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.2.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (1.23.5)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: langchain-openai in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (0.3.35)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.78 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-openai) (0.3.79)
# Collecting openai<3.0.0,>=1.104.2 (from langchain-openai)
#   Using cached openai-2.8.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.37)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (6.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.12.4)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.5.0)
# Requirement already satisfied: certifi in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.4)
# Requirement already satisfied: h11>=0.16 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (4.65.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2022.7.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.26.15)
# Using cached openai-2.8.1-py3-none-any.whl (1.0 MB)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.28.0
#     Uninstalling openai-0.28.0:
#       Successfully uninstalled openai-0.28.0
# Successfully installed openai-2.8.1
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pydantic in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (2.12.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic) (0.4.2)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement shutil (from versions: none)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ERROR: No matching distribution found for shutil
# Collecting openai==0.28
#   Using cached openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai==0.28) (2.32.5)
# Requirement already satisfied: tqdm in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai==0.28) (4.65.0)
# Requirement already satisfied: aiohttp in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai==0.28) (3.13.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai==0.28) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai==0.28) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai==0.28) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai==0.28) (2024.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai==0.28) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai==0.28) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai==0.28) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai==0.28) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai==0.28) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai==0.28) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai==0.28) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from multidict<7.0,>=4.5->aiohttp->openai==0.28) (4.15.0)
# Using cached openai-0.28.0-py3-none-any.whl (76 kB)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 2.8.1
#     Uninstalling openai-2.8.1:
#       Successfully uninstalled openai-2.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.3.35 requires openai<3.0.0,>=1.104.2, but you have openai 0.28.0 which is incompatible.
# Successfully installed openai-0.28.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install langchain==0.1.20
# !pip install "langchain-openai==0.1.1"
# !pip install "chromadb==0.4.22"
# !pip install "pydantic<2"
# !pip install tiktoken sentence-transformers
# Out:
# Collecting langchain==0.1.20
#   Downloading langchain-0.1.20-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain==0.1.20) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain==0.1.20) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain==0.1.20) (3.13.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain==0.1.20) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain==0.1.20) (0.6.7)
# Collecting langchain-community<0.1,>=0.0.38 (from langchain==0.1.20)
#   Downloading langchain_community-0.0.38-py3-none-any.whl.metadata (8.7 kB)
# Collecting langchain-core<0.2.0,>=0.1.52 (from langchain==0.1.20)
#   Using cached langchain_core-0.1.53-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain==0.1.20)
#   Downloading langchain_text_splitters-0.0.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.1.20)
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2,>=1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain==0.1.20) (1.23.5)
# Requirement already satisfied: pydantic<3,>=1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain==0.1.20) (2.12.4)
# Requirement already satisfied: requests<3,>=2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain==0.1.20) (2.32.5)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain==0.1.20)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.20) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.20) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.20) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.20) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.20) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.20) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.20) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.20) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.20) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain==0.1.20) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain==0.1.20) (23.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain==0.1.20) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.20) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.20) (3.11.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.20) (1.0.0)
# Requirement already satisfied: anyio in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.20) (3.5.0)
# Requirement already satisfied: certifi in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.20) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.20) (1.0.9)
# Requirement already satisfied: idna in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.20) (3.4)
# Requirement already satisfied: h11>=0.16 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.20) (0.16.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from multidict<7.0,>=4.5->aiohttp<4.0.0,>=3.8.3->langchain==0.1.20) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain==0.1.20) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain==0.1.20) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain==0.1.20) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain==0.1.20) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langchain==0.1.20) (1.26.15)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.20) (0.4.3)
# Requirement already satisfied: sniffio>=1.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.20) (1.2.0)
# Downloading langchain-0.1.20-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 7.8 MB/s  0:00:00 eta 0:00:01
# Downloading langchain_community-0.0.38-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 9.4 MB/s  0:00:00m eta 0:00:01
# Downloading langchain_core-0.1.53-py3-none-any.whl (303 kB)
# Downloading langchain_text_splitters-0.0.2-py3-none-any.whl (23 kB)
# Downloading langsmith-0.1.147-py3-none-any.whl (311 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, langsmith, langchain-core, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.1.2
#     Uninstalling tenacity-9.1.2:
#       Successfully uninstalled tenacity-9.1.2
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.4.37
#     Uninstalling langsmith-0.4.37:
#       Successfully uninstalled langsmith-0.4.37
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.79
#     Uninstalling langchain-core-0.3.79:
#       Successfully uninstalled langchain-core-0.3.79
#   Attempting uninstall: langchain-text-splitters━━━━━━━━━━━━━━━━━━ 2/6 [langchain-core]
#     Found existing installation: langchain-text-splitters 0.3.110m 2/6 [langchain-core]
#     Uninstalling langchain-text-splitters-0.3.11:━━━━━━━━━━━━━ 2/6 [langchain-core]
#       Successfully uninstalled langchain-text-splitters-0.3.11 2/6 [langchain-core]
#   Attempting uninstall: langchain━╸━━━━━━━━━━━━━ 4/6 [langchain-community]
#     Found existing installation: langchain 0.3.27m╺━━━━━━ 5/6 [langchain]unity]
#     Uninstalling langchain-0.3.27:━━━╺━━━━━━ 5/6 [langchain]
#       Successfully uninstalled langchain-0.3.27━━━━━━ 5/6 [langchain]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [langchain]/6 [langchain]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.3.35 requires langchain-core<1.0.0,>=0.3.78, but you have langchain-core 0.1.53 which is incompatible.
# langchain-openai 0.3.35 requires openai<3.0.0,>=1.104.2, but you have openai 0.28.0 which is incompatible.
# Successfully installed langchain-0.1.20 langchain-community-0.0.38 langchain-core-0.1.53 langchain-text-splitters-0.0.2 langsmith-0.1.147 tenacity-8.5.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Collecting langchain-openai==0.1.1
#   Using cached langchain_openai-0.1.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.33 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-openai==0.1.1) (0.1.53)
# Collecting openai<2.0.0,>=1.10.0 (from langchain-openai==0.1.1)
#   Using cached openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: tiktoken<1,>=0.5.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-openai==0.1.1) (0.12.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (6.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (0.1.147)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (2.12.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (8.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (3.11.4)
# Requirement already satisfied: requests<3,>=2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (1.0.0)
# Requirement already satisfied: anyio in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (3.5.0)
# Requirement already satisfied: certifi in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (1.0.9)
# Requirement already satisfied: idna in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (3.4)
# Requirement already satisfied: h11>=0.16 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai==0.1.1) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai==0.1.1) (0.12.0)
# Requirement already satisfied: sniffio in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai==0.1.1) (1.2.0)
# Requirement already satisfied: tqdm>4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai==0.1.1) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai==0.1.1) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.33->langchain-openai==0.1.1) (1.26.15)
# Requirement already satisfied: regex>=2022.1.18 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from tiktoken<1,>=0.5.2->langchain-openai==0.1.1) (2022.7.9)
# Downloading langchain_openai-0.1.1-py3-none-any.whl (32 kB)
# Using cached openai-1.109.1-py3-none-any.whl (948 kB)
# Installing collected packages: openai, langchain-openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.28.0
#     Uninstalling openai-0.28.0:
#       Successfully uninstalled openai-0.28.0
#   Attempting uninstall: langchain-openai━━━━━━━━ 0/2 [openai]
#     Found existing installation: langchain-openai 0.3.352 [openai]
#     Uninstalling langchain-openai-0.3.35:━━━ 0/2 [openai]
#       Successfully uninstalled langchain-openai-0.3.350/2 [openai]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [langchain-openai]
# Successfully installed langchain-openai-0.1.1 openai-1.109.1
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Collecting chromadb==0.4.22
#   Downloading chromadb-0.4.22-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: build>=1.0.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (1.3.0)
# Requirement already satisfied: requests>=2.28 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (2.32.5)
# Requirement already satisfied: pydantic>=1.9 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (2.12.4)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (0.99.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.22) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (1.23.5)
# Requirement already satisfied: posthog>=2.4.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (4.15.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (3.8.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (1.38.0)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb==0.4.22)
#   Downloading opentelemetry_instrumentation_fastapi-0.59b0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (5.2.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (6.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from chromadb==0.4.22) (5.2.0)
# Requirement already satisfied: packaging>=19.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb==0.4.22) (23.2)
# Requirement already satisfied: pyproject_hooks in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb==0.4.22) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb==0.4.22) (6.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb==0.4.22) (2.0.1)
# Collecting pydantic>=1.9 (from chromadb==0.4.22)
#   Using cached pydantic-1.10.24-cp39-cp39-macosx_11_0_arm64.whl.metadata (154 kB)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from fastapi>=0.95.2->chromadb==0.4.22) (0.27.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from starlette<0.28.0,>=0.27.0->fastapi>=0.95.2->chromadb==0.4.22) (3.5.0)
# Requirement already satisfied: idna>=2.8 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.95.2->chromadb==0.4.22) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.95.2->chromadb==0.4.22) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb==0.4.22) (3.11.0)
# Requirement already satisfied: certifi>=14.05.14 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (2.19.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (0.58.0)
# Requirement already satisfied: requests-oauthlib in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (1.3.1)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (1.26.15)
# Requirement already satisfied: durationpy>=0.7 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.22) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.22) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.22) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.4.22) (0.4.8)
# Requirement already satisfied: coloredlogs in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.22) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.22) (23.5.26)
# Requirement already satisfied: protobuf in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.22) (6.33.1)
# Requirement already satisfied: sympy in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb==0.4.22) (1.11.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.22) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.22) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.22) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-sdk>=1.2.0->chromadb==0.4.22) (0.59b0)
# Collecting opentelemetry-instrumentation-asgi==0.59b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.22)
#   Downloading opentelemetry_instrumentation_asgi-0.59b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.59b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.22)
#   Downloading opentelemetry_instrumentation-0.59b0-py3-none-any.whl.metadata (7.1 kB)
# Collecting opentelemetry-util-http==0.59b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.22)
#   Downloading opentelemetry_util_http-0.59b0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.22) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.59b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.22)
#   Downloading asgiref-3.10.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: backoff>=1.10.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb==0.4.22) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb==0.4.22) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.28->chromadb==0.4.22) (2.0.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb==0.4.22) (0.34.4)
# Requirement already satisfied: filelock in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.22) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.22) (2024.3.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.22) (1.1.9)
# Requirement already satisfied: click>=8.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from typer>=0.9.0->chromadb==0.4.22) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from typer>=0.9.0->chromadb==0.4.22) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from typer>=0.9.0->chromadb==0.4.22) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.4.22) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.4.22) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.4.22) (0.1.2)
# Requirement already satisfied: h11>=0.8 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.4.22) (0.16.0)
# Requirement already satisfied: httptools>=0.6.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.22) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.22) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.22) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.22) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.22) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.4.22) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb==0.4.22) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.22) (1.2.1)
# Downloading chromadb-0.4.22-py3-none-any.whl (509 kB)
# Using cached pydantic-1.10.24-cp39-cp39-macosx_11_0_arm64.whl (2.3 MB)
# Downloading opentelemetry_instrumentation_fastapi-0.59b0-py3-none-any.whl (13 kB)
# Downloading opentelemetry_instrumentation-0.59b0-py3-none-any.whl (33 kB)
# Downloading opentelemetry_instrumentation_asgi-0.59b0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.59b0-py3-none-any.whl (7.6 kB)
# Downloading asgiref-3.10.0-py3-none-any.whl (24 kB)
# Installing collected packages: pydantic, opentelemetry-util-http, asgiref, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.4
#     Uninstalling pydantic-2.12.4:
#       Successfully uninstalled pydantic-2.12.4
#   Attempting uninstall: chromadb
#     Found existing installation: chromadb 1.3.4
#     Uninstalling chromadb-1.3.4:━━━━━━━━━━╺━━━━━ 6/7 [chromadb]
#       Successfully uninstalled chromadb-1.3.40m╺━━━━━ 6/7 [chromadb]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [chromadb]6/7 [chromadb]
# Successfully installed asgiref-3.10.0 chromadb-0.4.22 opentelemetry-instrumentation-0.59b0 opentelemetry-instrumentation-asgi-0.59b0 opentelemetry-instrumentation-fastapi-0.59b0 opentelemetry-util-http-0.59b0 pydantic-1.10.24
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pydantic<2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (1.10.24)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from pydantic<2) (4.15.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tiktoken in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (0.12.0)
# Requirement already satisfied: sentence-transformers in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (5.1.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: requests>=2.26.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (2.2.0)
# Requirement already satisfied: scikit-learn in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (0.34.4)
# Requirement already satisfied: Pillow in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.3.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2024.2.2)
# Requirement already satisfied: sympy in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: networkx in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (2.8.4)
# Requirement already satisfied: jinja2 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: joblib>=1.1.1 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.2.1)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas

# %%
import pandas

# %%
pip install langchain langchain-core langchain-openai
# Out:
# Collecting langchain
#   Downloading langchain-1.0.7-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core
#   Downloading langchain_core-1.0.5-py3-none-any.whl.metadata (3.6 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.0.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain)
#   Downloading langgraph-1.0.3-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from langchain) (2.12.4)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core)
#   Downloading langsmith-0.4.43-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from langchain-core) (4.15.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_prebuilt-1.0.4-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading xxhash-3.6.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading ormsgpack-1.12.0-cp310-cp310-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (1.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core)
#   Downloading zstandard-0.25.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting openai<3.0.0,>=1.109.1 (from langchain-openai)
#   Using cached openai-2.8.1-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Downloading jiter-0.12.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2025.11.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bhubeshsr/opt/anaconda3/envs/rag/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.3.0)
# Downloading langchain-1.0.7-py3-none-any.whl (93 kB)
# Downloading langchain_core-1.0.5-py3-none-any.whl (471 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.0.3-py3-none-any.whl (156 kB)
# Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Downloading langgraph_prebuilt-1.0.4-py3-none-any.whl (34 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading langsmith-0.4.43-py3-none-any.whl (410 kB)
# Downloading langchain_openai-1.0.3-py3-none-any.whl (82 kB)
# Using cached openai-2.8.1-py3-none-any.whl (1.0 MB)
# Downloading jiter-0.12.0-cp310-cp310-macosx_11_0_arm64.whl (319 kB)
# Downloading tiktoken-0.12.0-cp310-cp310-macosx_11_0_arm64.whl (995 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 995.8/995.8 kB 9.8 MB/s  0:00:00
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading ormsgpack-1.12.0-cp310-cp310-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (369 kB)
# Downloading regex-2025.11.3-cp310-cp310-macosx_11_0_arm64.whl (288 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading xxhash-3.6.0-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
# Downloading zstandard-0.25.0-cp310-cp310-macosx_11_0_arm64.whl (640 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 640.6/640.6 kB 8.9 MB/s  0:00:00
# Installing collected packages: zstandard, xxhash, regex, ormsgpack, jsonpointer, jiter, tiktoken, requests-toolbelt, jsonpatch, openai, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langchain-openai, langgraph-prebuilt, langgraph, langchain
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [langchain]18 [langgraph]core]
# Successfully installed jiter-0.12.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-1.0.7 langchain-core-1.0.5 langchain-openai-1.0.3 langgraph-1.0.3 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.4 langgraph-sdk-0.2.9 langsmith-0.4.43 openai-2.8.1 ormsgpack-1.12.0 regex-2025.11.3 requests-toolbelt-1.0.0 tiktoken-0.12.0 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import shutil
from dataclasses import dataclass

from langchain.llms import OpenAI
from langchain.embeddings import OpenAIEmbeddings
from langchain.evaluation import load_evaluator
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain.vectorstores.chroma import Chroma
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

from typing import List
from langchain.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field, NonNegativeInt
from langchain.prompts import PromptTemplate

# %%
import os
import openai

os.environ["OPENAI_API_KEY"] = "YOUR API KEY"
os.environ["OPENAI_BASE_URL"] = "https://openai.vocareum.com/v1"

openai.api_key = "YOUR API KEY"
openai.api_base = "https://openai.vocareum.com/v1"


prompt = """
Generate 10 synthetic real estate listings.
Return ONLY valid CSV format (no backticks, no commentary).
Columns:
Neighborhood,Price,Bedrooms,Bathrooms,House Size,Description

Rules:
- Bedrooms must be an integer between 1 and 5.
- Bathrooms must be an integer between 1 and 4.
- Price must be a realistic positive number.
- House Size must be a positive number in square feet.
- Add a proper in detail description for each estate.
- There should not be any None/Null/Void Cell in the CSV
"""

response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[{"role": "user", "content": prompt}],
    temperature=0.5
)

csv_text = response.choices[0].message.content.strip()

# Save directly as CSV file
with open("listings.csv", "w", encoding="utf-8") as f:
    f.write(csv_text)

print("CSV generated successfully: listings.csv")

# %%
from langchain.vectorstores.chroma import Chroma

# %%
# Environment variables
OPENAI_API_KEY = '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'
os.environ['OPENAI_API_KEY']= OPENAI_API_KEY

# %%
MODEL_NAME = 'openai/gpt-3.5-turbo'

# %%
llm = OpenAI(model_name=MODEL_NAME, temperature=0, api_key=OPENAI_API_KEY , openai_api_base="https://openrouter.ai/api/v1")
# Out:
# /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %%
INSTRUCTION = "Generate a CSV file with at least 10 real estate listings."
SAMPLE_LISTING = \
"""
Neighborhood: Green Oaks
Price: $800,000
Bedrooms: 3
Bathrooms: 2
House Size: 2,000 sqft

Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.

Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
"""

# %%
class RealEstateListing(BaseModel):
    """
    A real estate listing.
    
    Attributes:
    - neighborhood: str
    - price: NonNegativeInt
    - bedrooms: NonNegativeInt
    - bathrooms: NonNegativeInt
    - house_size: NonNegativeInt
    - description: str
    - neighborhood_description: str
    """
    neighborhood: str = Field(description="The neighborhood where the property is located")
    price: NonNegativeInt = Field(description="The price of the property in USD")
    bedrooms: NonNegativeInt = Field(description="The number of bedrooms in the property")
    bathrooms: NonNegativeInt = Field(description="The number of bathrooms in the property")
    house_size: NonNegativeInt = Field(description="The size of the house in square feet")
    description: str = Field(description="A description of the property")
    neighborhood_description: str = Field(description="A description of the neighborhood.")  

class ListingCollection(BaseModel):
    """
    A collection of real estate listings.
    
    Attributes:
    - listings: List[RealEstateListing]
    """
    listings: List[RealEstateListing] = Field(description="A list of real estate listings")

# %%
parser = PydanticOutputParser(pydantic_object=ListingCollection)

# %%
# printing the prompt
prompt = PromptTemplate(
    template="{instruction}\n{sample}\n{format_instructions}\n",
    input_variables=["instruction", "sample"],
    partial_variables={"format_instructions": parser.get_format_instructions},
)

query = prompt.format(
    instruction=INSTRUCTION,
    sample=SAMPLE_LISTING,
)
print(query)
# Out:
# Generate a CSV file with at least 10 real estate listings.
#
# Neighborhood: Green Oaks
# Price: $800,000
# Bedrooms: 3
# Bathrooms: 2
# House Size: 2,000 sqft
#
# Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem.
#
# Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"description": "A collection of real estate listings.\n\nAttributes:\n- listings: List[RealEstateListing]", "properties": {"listings": {"title": "Listings", "description": "A list of real estate listings", "type": "array", "items": {"$ref": "#/definitions/RealEstateListing"}}}, "required": ["listings"], "definitions": {"RealEstateListing": {"title": "RealEstateListing", "description": "A real estate listing.\n\nAttributes:\n- neighborhood: str\n- price: NonNegativeInt\n- bedrooms: NonNegativeInt\n- bathrooms: NonNegativeInt\n- house_size: NonNegativeInt\n- description: str\n- neighborhood_description: str", "type": "object", "properties": {"neighborhood": {"title": "Neighborhood", "description": "The neighborhood where the property is located", "type": "string"}, "price": {"title": "Price", "description": "The price of the property in USD", "minimum": 0, "type": "integer"}, "bedrooms": {"title": "Bedrooms", "description": "The number of bedrooms in the property", "minimum": 0, "type": "integer"}, "bathrooms": {"title": "Bathrooms", "description": "The number of bathrooms in the property", "minimum": 0, "type": "integer"}, "house_size": {"title": "House Size", "description": "The size of the house in square feet", "minimum": 0, "type": "integer"}, "description": {"title": "Description", "description": "A description of the property", "type": "string"}, "neighborhood_description": {"title": "Neighborhood Description", "description": "A description of the neighborhood.", "type": "string"}}, "required": ["neighborhood", "price", "bedrooms", "bathrooms", "house_size", "description", "neighborhood_description"]}}}
# ```

# %%
llm = ChatOpenAI(
    model_name=MODEL_NAME,
    temperature=0,
    api_key=OPENAI_API_KEY, # Use the API key
    openai_api_base="https://openrouter.ai/api/v1" # Specify the custom base URL
)
# Out:
# /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
response_msg = llm.invoke(query)
response_content = response_msg.content

# %%
# create a dataframe from the response
result = parser.parse(response_content)
data_list = [item.dict() for item in result.listings]
df = pd.DataFrame(data_list)
df.head()
# Out:
#         neighborhood    price  bedrooms  bathrooms  house_size  \
# 0         Green Oaks   800000         3          2        2000
# 1          Sunnyvale   950000         4          3        2500
# 2   Brooklyn Heights  1200000         5          4        3500
# 3  Pacific Palisades  3500000         6          5        5000
# 4        South Beach  1500000         2          2        1800
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Located in the desirable neighborhood of Sunny...
# 2  Welcome to this stunning 5-bedroom, 4-bathroom...
# 3  Experience luxury living in this exquisite 6-b...
# 4  Live the urban lifestyle in this sleek 2-bedro...
#
#                             neighborhood_description
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Sunnyvale is known for its top-rated schools, ...
# 2  Brooklyn Heights is a vibrant community with t...
# 3  Pacific Palisades is a prestigious coastal com...
# 4  South Beach is a vibrant neighborhood with tre...

# %%
df
# Out:
#         neighborhood    price  bedrooms  bathrooms  house_size  \
# 0         Green Oaks   800000         3          2        2000
# 1          Sunnyvale   950000         4          3        2500
# 2   Brooklyn Heights  1200000         5          4        3500
# 3  Pacific Palisades  3500000         6          5        5000
# 4        South Beach  1500000         2          2        1800
# 5      Beverly Hills  5000000         7          6        8000
# 6    Upper West Side  2000000         4          3        3000
# 7         Georgetown  1800000         5          4        3200
# 8       Palm Springs  1200000         3          3        2200
# 9            Tribeca  3000000         4          3        2800
#
#                                          description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Located in the desirable neighborhood of Sunny...
# 2  Welcome to this stunning 5-bedroom, 4-bathroom...
# 3  Experience luxury living in this exquisite 6-b...
# 4  Live the urban lifestyle in this sleek 2-bedro...
# 5  Step into luxury in this magnificent 7-bedroom...
# 6  Welcome to this elegant 4-bedroom, 3-bathroom ...
# 7  Experience historic charm in this 5-bedroom, 4...
# 8  Escape to paradise in this 3-bedroom, 3-bathro...
# 9  Live in luxury in this 4-bedroom, 3-bathroom l...
#
#                             neighborhood_description
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Sunnyvale is known for its top-rated schools, ...
# 2  Brooklyn Heights is a vibrant community with t...
# 3  Pacific Palisades is a prestigious coastal com...
# 4  South Beach is a vibrant neighborhood with tre...
# 5  Beverly Hills is synonymous with luxury, offer...
# 6  The Upper West Side is a cultural hub with wor...
# 7  Georgetown is a picturesque neighborhood with ...
# 8  Palm Springs is a desert oasis known for its m...
# 9  Tribeca is a trendy neighborhood with cobblest...

# %%
df.to_csv('real_estate_listings.csv', index_label = 'id')

# %%
import os
import shutil
import pandas as pd
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings # Corrected import for modern LangChain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.docstore.document import Document

# --- 1. DEFINE YOUR OPENROUTER SETTINGS ---
OPENROUTER_API_KEY = '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' # ⚠️ Make sure this is set!
OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"
DEFAULT_SITE_URL = "http://localhost:8080" # Required referrer for free models
os.environ["OPENAI_API_KEY"] = OPENROUTER_API_KEY

# --- THE FIX: Change CHROMA_PATH to use /tmp ---
CHROMA_PATH = "chroma3" # We are now saving in the system's temp folder
CSV_PATH = "real_estate_listings.csv"


# --- 2. CREATE THE CONFIGURED EMBEDDING FUNCTION ---
embedding_function = OpenAIEmbeddings(
    openai_api_key=OPENROUTER_API_KEY,
    openai_api_base=OPENROUTER_BASE_URL,
    default_headers={
        "HTTP-Referer": DEFAULT_SITE_URL
    }
)



# --- 3. LOAD, SPLIT, AND SAVE (No changes here) ---
df = pd.read_csv(CSV_PATH)
documents = []

for index, row in df.iterrows():
    documents.append(Document(page_content=row['description'], metadata={'id': str(index)}))

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=100,
    length_function=len,
    add_start_index=True,
)
chunks = text_splitter.split_documents(documents)
print(f"Split {len(documents)} documents into {len(chunks)} chunks.")


if chunks:
    document = chunks[10]
    print(document.page_content)
    print(document.metadata)

# --- 4. SAVE TO THE NEW /tmp PATH ---
# We still clear it first, just to be safe

if os.path.exists(CHROMA_PATH):
    print(f"Removing old database from {CHROMA_PATH}...")
    shutil.rmtree(CHROMA_PATH)

# We don't even need chmod. /tmp is designed to be writable.
os.makedirs(CHROMA_PATH, exist_ok=True)
print(f"Created new directory at {CHROMA_PATH}.")

print("Attempting to save to Chroma...")
db = Chroma.from_documents(
    chunks,
    embedding_function, # <-- Use the pre-configured instance
    persist_directory=CHROMA_PATH
)
db.persist()
print(f"Successfully saved {len(chunks)} chunks to {CHROMA_PATH}.")

# Working
# Out:
# Split 10 documents into 21 chunks.
# offers a walk-in closet and en-suite bathroom. Enjoy city views from the private balcony or relax in the rooftop pool and lounge.
# {'id': '4', 'start_index': 201}
# Created new directory at chroma3.
# Attempting to save to Chroma...
# Successfully saved 21 chunks to chroma3.
# /Users/bhubeshsr/opt/anaconda3/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   warn_deprecated(

# %%
# Out:
# Chroma DB Path: chroma1
# Created writable directory: chroma1
# Loaded 10 documents.
# Split 10 documents into 21 chunks.
#
# Sample chunk text:
# kitchen with stainless steel appliances. The master suite offers a walk-in closet and a luxurious en-suite bathroom. Relax on the private balcony with city views or take advantage of the building's amenities, including a rooftop pool and fitness center.
# Metadata: {'id': '4', 'start_index': 196}
#
# Saving chunks into ChromaDB...
# SUCCESS: Saved 21 chunks to chroma1

# %%
def predict_response(query_text, PROMPT_TEMPLATE):
    embedding_function = OpenAIEmbeddings(
        openai_api_key=OPENROUTER_API_KEY,
        openai_api_base=OPENROUTER_BASE_URL,
        default_headers={"HTTP-Referer": DEFAULT_SITE_URL},
    )

    db = Chroma(persist_directory=CHROMA_PATH, embedding_function=embedding_function)

    results = db.similarity_search_with_relevance_scores(query_text, k=3)

    if len(results) == 0 or results[0][1] < 0.7:
        print("No matching results.")
        return

    context_text = "\n\n---\n\n".join([doc.page_content for doc, _ in results])

    prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
    prompt = prompt_template.format(context=context_text, question=query_text)

    model = ChatOpenAI(
        temperature=0.7,
        api_key=OPENROUTER_API_KEY,
        openai_api_base=OPENROUTER_BASE_URL,
    )

    response = model.invoke(prompt).content

    print("\n=============================")
    print("🔹 RESPONSE")
    print("=============================")
    print(response)

    print("\n=============================")
    print("🔹 SOURCES")
    print("=============================")

    for doc, score in results:
        print(f"ID: {doc.metadata.get('id')} | Score: {score}")
        print(doc.page_content)
        print("------------------------")

# %%
###############################################################
# CLEAN STEP 1 — SEMANTIC SEARCH OF LISTINGS
###############################################################

from langchain_openai import ChatOpenAI
from langchain_community.vectorstores import Chroma

# Build retriever
retriever = db.as_retriever(search_kwargs={"k": 5})

query = "Find a safe neighborhood with 3 bedrooms and a good backyard."

results = retriever.get_relevant_documents(query)

print("=============================================")
print("🔍 STEP 1 — SEMANTIC SEARCH RESULTS")
print("=============================================")

for i, doc in enumerate(results, start=1):
    print(f"\n--- Result {i} ---")
    print(f"Listing ID: {doc.metadata.get('id')}")
    print(f"Description: {doc.page_content}")
    print("---------------------------------------------")


###############################################################
# CLEAN STEP 2 — PERSONALIZATION (Conversation Summary Memory)
###############################################################

from langchain.memory import ConversationSummaryMemory, ChatMessageHistory

personal_questions = [
    "What is your ideal number of bedrooms?",
    "What kind of neighborhood do you prefer?",
    "What is your maximum budget?",
    "Which amenities matter most to you?",
    "Do you prefer urban, suburban, or semi-urban areas?"
]

answers = [
    "I want 3 bedrooms.",
    "A quiet and family-friendly neighborhood.",
    "My maximum budget is 90 lakhs.",
    "Nearby schools, park, and parking.",
    "I prefer suburban areas."
]

history = ChatMessageHistory()

# Simulated conversation
history.add_user_message("Start preference collection.")

for q, a in zip(personal_questions, answers):
    history.add_ai_message(q)
    history.add_user_message(a)

# Summarize preferences
summary_llm = ChatOpenAI(
    model_name="gpt-3.5-turbo",
    temperature=0,
    api_key=OPENAI_API_KEY,
    openai_api_base="https://openrouter.ai/api/v1",
)

memory = ConversationSummaryMemory(
    llm=summary_llm,
    chat_memory=history,
    memory_key="summary",
    input_key="question",
    buffer="Summarize clearly:"
)

memory.load_memory_variables({"question": "Summarize my home preferences."})
summary_text = memory.buffer

print("\n=============================================")
print("📝 STEP 2 — USER PREFERENCE SUMMARY")
print("=============================================")
print(summary_text)


###############################################################
# CLEAN STEP 3 — PERSONALIZED RAG RECOMMENDATION
###############################################################

from langchain.prompts import PromptTemplate
from langchain.chains import ConversationalRetrievalChain

personalized_prompt = PromptTemplate(
    template="""
You are a smart real estate advisor.

User Preferences Summary:
{summary}

Retrieved Property Information:
{context}

User Question:
{question}

Provide a friendly, helpful recommendation (max 5 sentences).
Explain clearly how the listing matches the user's preferences.
""",
    input_variables=["summary", "context", "question"]
)

rag_chain = ConversationalRetrievalChain.from_llm(
    llm=ChatOpenAI(
        model_name="gpt-3.5-turbo",
        temperature=0,
        api_key=OPENAI_API_KEY,
        openai_api_base="https://openrouter.ai/api/v1"
    ),
    retriever=retriever,
    chain_type="stuff",
    combine_docs_chain_kwargs={"prompt": personalized_prompt},
    memory=memory
)

final_query = "Recommend the best house for me."

response = personalized_chain({"question": final_query,
                             "chat_history":[]})

print("\n=============================================")
print("🏡 STEP 3 — PERSONALIZED RAG RECOMMENDATION")
print("=============================================")
print(response["answer"])


###############################################################
# CLEAN STEP 3B — Show Sources Used
###############################################################

print("\n=============================================")
print("📚 SOURCES (IDs & Text Used for Recommendation)")
print("=============================================")

for i, doc in enumerate(results, start=1):
    print(f"\n--- Source {i} ---")
    print(f"Listing ID: {doc.metadata.get('id')}")
    print(doc.page_content)
    print("---------------------------------------------")
# Out:
# =============================================
# 🔍 STEP 1 — SEMANTIC SEARCH RESULTS
# =============================================
#
# --- Result 1 ---
# Listing ID: 7
# Description: area, walk-in closet, and spa-like bathroom. Relax in the landscaped backyard or walk to the nearby shops and restaurants.
# ---------------------------------------------
#
# --- Result 2 ---
# Listing ID: 2
# Description: The spacious living areas include a formal dining room, library, and sunroom. The landscaped backyard offers a peaceful retreat in the heart of the city.
# ---------------------------------------------
#
# --- Result 3 ---
# Listing ID: 8
# Description: Escape to paradise in this 3-bedroom, 3-bathroom mid-century modern home in Palm Springs. The open floor plan features vaulted ceilings, clerestory windows, and a gourmet kitchen. The master suite offers a walk-in closet and en-suite bathroom. Relax in the backyard oasis with a pool, spa, and
# ---------------------------------------------
#
# --- Result 4 ---
# Listing ID: 8
# Description: offers a walk-in closet and en-suite bathroom. Relax in the backyard oasis with a pool, spa, and mountain views.
# ---------------------------------------------
#
# --- Result 5 ---
# Listing ID: 1
# Description: Located in the desirable neighborhood of Sunnyvale, this spacious 4-bedroom, 3-bathroom home offers modern amenities and a prime location. The open floor plan is perfect for entertaining, with a gourmet kitchen, formal dining room, and cozy living area. The master suite features a luxurious en-suite
# ---------------------------------------------
#
# =============================================
# 📝 STEP 2 — USER PREFERENCE SUMMARY
# =============================================
# Summarize clearly:
#
# =============================================
# 🏡 STEP 3 — PERSONALIZED RAG RECOMMENDATION
# =============================================
# 1. I highly recommend the mid-century modern home in Palm Springs with 3 bedrooms, 3 bathrooms, a pool, spa, and eco-conscious features. This property offers a spacious layout, luxurious amenities, and a peaceful neighborhood, making it the perfect match for your preferences. You'll love the open floor plan, vaulted ceilings, and backyard oasis for relaxation and entertainment.
#
# 2. This property aligns perfectly with your desire for a spacious home with amenities such as a pool and spa. The mid-century modern design and eco-conscious features add a touch of luxury and sustainability to your living space. The peaceful neighborhood in Palm Springs provides a serene environment for you to unwind and enjoy the beautiful mountain views.
#
# =============================================
# 📚 SOURCES (IDs & Text Used for Recommendation)
# =============================================
#
# --- Source 1 ---
# Listing ID: 7
# area, walk-in closet, and spa-like bathroom. Relax in the landscaped backyard or walk to the nearby shops and restaurants.
# ---------------------------------------------
#
# --- Source 2 ---
# Listing ID: 2
# The spacious living areas include a formal dining room, library, and sunroom. The landscaped backyard offers a peaceful retreat in the heart of the city.
# ---------------------------------------------
#
# --- Source 3 ---
# Listing ID: 8
# Escape to paradise in this 3-bedroom, 3-bathroom mid-century modern home in Palm Springs. The open floor plan features vaulted ceilings, clerestory windows, and a gourmet kitchen. The master suite offers a walk-in closet and en-suite bathroom. Relax in the backyard oasis with a pool, spa, and
# ---------------------------------------------
#
# --- Source 4 ---
# Listing ID: 8
# offers a walk-in closet and en-suite bathroom. Relax in the backyard oasis with a pool, spa, and mountain views.
# ---------------------------------------------
#
# --- Source 5 ---
# Listing ID: 1
# Located in the desirable neighborhood of Sunnyvale, this spacious 4-bedroom, 3-bathroom home offers modern amenities and a prime location. The open floor plan is perfect for entertaining, with a gourmet kitchen, formal dining room, and cozy living area. The master suite features a luxurious en-suite
# ---------------------------------------------
